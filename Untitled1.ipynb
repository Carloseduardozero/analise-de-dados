# %% [markdown]
# <a href="https://colab.research.google.com/github/Carloseduardozero/analise-de-dados/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Lendo o arquivo Excel
arquivo = pd.read_excel("/content/afc6ccc0-62a1-4a69-82fa-054abbe95ca6.xlsx")

# %%
# Mostrando as 5 primeiras linhas
print("🔹 Primeiras linhas do dataset:")
print(arquivo.head())
# Out:
# 🔹 Primeiras linhas do dataset:
#   Unnamed: 0 Interior ou Reg.Metropolitana     Totais          Totais.1  \
# 0         UF                     Município  População  Casos Acumulados
# 1     Totais                           NaN  210147125          39318227
# 2         AC                           NaN     881935            174977
# 3         AL                           NaN    3337357            351119
# 4         AM                           NaN    4144597            649618
#
#                             Totais.2           Totais.3  \
# 0  Incidência covid-19 (100 mil hab)  Óbitos Acumulados
# 1                       18709.857201             716626
# 2                       19840.124272               2118
# 3                       10520.870258               7380
# 4                       15673.852005              14556
#
#                          Totais.4 Reg. Metropolitana Reg. Metropolitana.1  \
# 0  Taxa mortalidade (100 mil hab)          População     Casos Acumulados
# ...

# %%
print(arquivo.columns)
# Out:
# Index(['Unnamed: 0', 'Interior ou Reg.Metropolitana', 'Totais', 'Totais.1',
#        'Totais.2', 'Totais.3', 'Totais.4', 'Reg. Metropolitana',
#        'Reg. Metropolitana.1', 'Reg. Metropolitana.2', 'Reg. Metropolitana.3',
#        'Reg. Metropolitana.4', 'Interior', 'Interior.1', 'Interior.2',
#        'Interior.3', 'Interior.4'],
#       dtype='object')

# %%
# Informações gerais
print("\n🔹 Informações gerais do dataset:")
print(arquivo.info())
# Out:
# 🔹 Informações gerais do dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     169 non-null    object
#  1   Interior ou Reg.Metropolitana  141 non-null    object
#  2   Totais                         169 non-null    object
#  3   Totais.1                       169 non-null    object
#  4   Totais.2                       169 non-null    object
#  5   Totais.3                       169 non-null    object
#  6   Totais.4                       169 non-null    object
#  7   Reg. Metropolitana             169 non-null    object
#  8   Reg. Metropolitana.1           169 non-null    object
#  9   Reg. Metropolitana.2           169 non-null    object
#  10  Reg. Metropolitana.3           169 non-null    object
#  11  Reg. Metropolitana.4           169 non-null    object
# ...

# %%
# Estatísticas descritivas
print("\n🔹 Estatísticas descritivas:")
print(arquivo[['Reg. Metropolitana.1', 'Totais.4', 'Interior', 'Interior.4']].describe())
# Out:
# 🔹 Estatísticas descritivas:
#        Reg. Metropolitana.1                                     Totais.4  \
# count                   169                                          169
# unique                   46                                           32
# top                       -  O cálculo requer população >= a 100.000 hab
# freq                    124                                          138
#
#        Interior                                   Interior.4
# count       169                                          169
# unique      153                                           31
# top           -  O cálculo requer população >= a 100.000 hab
# freq         17                                          123

# %%
print("\n🔹 Estatísticas descritivas:")
print(arquivo.describe())
# Out:
# 🔹 Estatísticas descritivas:
#        Unnamed: 0 Interior ou Reg.Metropolitana     Totais  Totais.1 Totais.2  \
# count         169                           141        169       169      169
# unique         29                           141        169       165       32
# top            TO                     Município  População       642        -
# freq          141                             1          1         2      138
#
#         Totais.3                                     Totais.4  \
# count        169                                          169
# unique        77                                           32
# top            4  O cálculo requer população >= a 100.000 hab
# freq          10                                          138
#
#        Reg. Metropolitana Reg. Metropolitana.1 Reg. Metropolitana.2  \
# count                 169                  169                  169
# unique                 46                   46                   31
# ...

# %%
arquivo.describe(percentiles=[0.3, 0.5, 0.7])
# Out:
#        Unnamed: 0 Interior ou Reg.Metropolitana     Totais  Totais.1 Totais.2  \
# count         169                           141        169       169      169
# unique         29                           141        169       165       32
# top            TO                     Município  População       642        -
# freq          141                             1          1         2      138
#
#         Totais.3                                     Totais.4  \
# count        169                                          169
# unique        77                                           32
# top            4  O cálculo requer população >= a 100.000 hab
# freq          10                                          138
#
#        Reg. Metropolitana Reg. Metropolitana.1 Reg. Metropolitana.2  \
# count                 169                  169                  169
# unique                 46                   46                   31
# ...

# %%
arquivo.describe(exclude=[int])
# Out:
#        Unnamed: 0 Interior ou Reg.Metropolitana     Totais  Totais.1 Totais.2  \
# count         169                           141        169       169      169
# unique         29                           141        169       165       32
# top            TO                     Município  População       642        -
# freq          141                             1          1         2      138
#
#         Totais.3                                     Totais.4  \
# count        169                                          169
# unique        77                                           32
# top            4  O cálculo requer população >= a 100.000 hab
# freq          10                                          138
#
#        Reg. Metropolitana Reg. Metropolitana.1 Reg. Metropolitana.2  \
# count                 169                  169                  169
# unique                 46                   46                   31
# ...

# %%
arquivo.info(show_counts=True, memory_usage=True, verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     169 non-null    object
#  1   Interior ou Reg.Metropolitana  141 non-null    object
#  2   Totais                         169 non-null    object
#  3   Totais.1                       169 non-null    object
#  4   Totais.2                       169 non-null    object
#  5   Totais.3                       169 non-null    object
#  6   Totais.4                       169 non-null    object
#  7   Reg. Metropolitana             169 non-null    object
#  8   Reg. Metropolitana.1           169 non-null    object
#  9   Reg. Metropolitana.2           169 non-null    object
#  10  Reg. Metropolitana.3           169 non-null    object
#  11  Reg. Metropolitana.4           169 non-null    object
# ...
